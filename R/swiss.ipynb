# %%
head(swiss)
# Out:
#              Fertility Agriculture Examination Education Catholic
# Courtelary   80.2      17.0        15          12         9.96
# Delemont     83.1      45.1         6           9        84.84
# Franches-Mnt 92.5      39.7         5           5        93.40
# Moutier      85.8      36.5        12           7        33.77
# Neuveville   76.9      43.5        17          15         5.16
# Porrentruy   76.1      35.3         9           7        90.57
#              Infant.Mortality
# Courtelary   22.2
# Delemont     22.2
# Franches-Mnt 20.2
# Moutier      20.3
# Neuveville   20.6
# Porrentruy   26.6

# %%
plot(swiss$Fertility)
# Out:
# plot without title

# %%
plot(swiss$Fertility,swiss$Agriculture)
# Out:
# plot without title

# %%
plot(swiss$Fertility,swiss$Agriculture, main='swiss data', xlab='Fertility',ylab='Agriculture')
# Out:
# Plot with title "swiss data"

# %%
hist(swiss$Fertility)
# Out:
# Plot with title "Histogram of swiss$Fertility"

# %%
hist(swiss$Fertility,freq=FALSE)
# Out:
# Plot with title "Histogram of swiss$Fertility"
